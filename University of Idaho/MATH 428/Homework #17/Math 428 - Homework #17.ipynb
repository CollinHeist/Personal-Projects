# %% [markdown]
# # Math 428 - Homework for 04/22/19
#
# ## Problem 25.16
#
# $$m\frac{d^2x}{dt^2}+c\frac{dx}{dt}+kx=0$$
#
# With $m=20kg$, $c=5, 40, 200 Ns/m$, $k=20N/m$, $x'(0)=0$, $x(0)=1m$. Solve for $0\leq t\leq 15$.
#
# $$\frac{dx}{dt}=z$$
#
# $$\frac{d^2x}{dt^2}=\frac{dz}{dt}=\frac{-kx-cz}{m}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Euler method for two simulataneous ODEs
def euler_ode(dy_dx, dz_dx, initial=[0, 0], bounds=[0, 0], h=0.1, c_val=5):
    x, y = [initial[0]], [initial[1]]
    for i in range(1, int((bounds[1] - bounds[0]) / h) + 1):
        x_n, y_n = x[-1], y[-1]
        
        k1 = h * dy_dx(x_n, y_n)
        m1 = h * dz_dx(x_n, y_n, c_val)
        
        x.append(x_n + k1)
        y.append(y_n + m1)
        
    return x, y

# %%
# Function definition of dx/dt
def dx_dt(x, z):
    return z

# Function definition of dx2/dt2
def dz_dt(x, z, c):
    return (-20 * x - c * z) / 20

def calc_min_h(k, m, c):
    return -2 / ((-k - m) / c)

# %% [markdown]
# ## Solution to the differential equation with $c=5$

# %%
k, m, c1, c2, c3 = 20, 20, 5, 40, 200
# Generate the time-axis, c1
step5_xl, step5_l = calc_min_h(k, m, c1) * 2, calc_min_h(k, m, c1) * 1.2
step5_m, step5_s  = calc_min_h(k, m, c1) * 0.8, calc_min_h(k, m, c1) * 0.5
t5_xl, t5_l = np.arange(0, 15 + step5_xl, step5_xl), np.arange(0, 15 + step5_l, step5_l)
t5_m, t5_s = np.arange(0, 15 + step5_m, step5_m), np.arange(0, 15 + step5_s, step5_s)

# Numerically solve the ODEs
x5_xl, _ = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step5_xl, c1)
x5_l, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step5_l, c1)
x5_m, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step5_m, c1)
x5_s, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step5_s, c1)

# Plot the resulting solutions
plt.figure(figsize=(18, 12), dpi=250)
plt.plot(t5_xl, x5_xl, label="x(t), k=5 N/m, h=%0.3f" % step5_xl)
plt.plot(t5_l, x5_l, label="x(t), k=5 N/m, h=%0.3f" % step5_l)
plt.plot(t5_m, x5_m, label="x(t), k=5 N/m, h=%0.3f" % step5_m)
plt.plot(t5_s, x5_s, label="x(t), k=5 N/m, h=%0.3f" % step5_s)
plt.xlabel("$t$ (s)")
plt.ylabel("$x$ (m)")
plt.grid(True)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Solution to the differential equation with $c=40$

# %%
# Generate the time-axis, c2
step40_xl, step40_l = calc_min_h(k, m, c2) * 0.95, calc_min_h(k, m, c2) * 0.8
step40_m, step40_s  = calc_min_h(k, m, c2) * 0.55, calc_min_h(k, m, c2) * 0.25
t40_xl, t40_l = np.arange(0, 15 + step40_xl, step40_xl), np.arange(0, 15 + step40_l, step40_l)
t40_m, t40_s = np.arange(0, 15 + step40_m, step40_m), np.arange(0, 15 + step40_s, step40_s)

# The solution to the ODE 
x40_xl, _ = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step40_xl, c2)
x40_l, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step40_l, c2)
x40_m, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step40_m, c2)
x40_s, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step40_s, c2)

# Plot the resulting solutions
plt.figure(figsize=(18, 12), dpi=250)
plt.plot(t40_xl[:-1], x40_xl, label="x(t), k=40 N/m, h=%0.3f" % step40_xl)
plt.plot(t40_l, x40_l, label="x(t), k=40 N/m, h=%0.3f" % step40_l)
plt.plot(t40_m[:-1], x40_m, label="x(t), k=40 N/m, h=%0.3f" % step40_m)
plt.plot(t40_s, x40_s, label="x(t), k=40 N/m, h=%0.3f" % step40_s)
plt.xlabel("$t$ (s)")
plt.ylabel("$x$ (m)")
plt.grid(True)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Solution to the differential equation with $c=200$

# %%
x200_xl, _ = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step_xl, c1)
x200_l, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step_l, c1)
x200_m, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step_m, c1)
x200_s, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step_s, c1)

# Generate the time-axis, c2
# step200_xl, step200_l = calc_min_h(k, m, c3) * 1.2, calc_min_h(k, m, c3) * 1
# step200_m, step200_s  = calc_min_h(k, m, c3) * 0.75, calc_min_h(k, m, c3) * 0.5
step200_xl, step200_l, step200_m, step200_s = 0.21, 0.1, 0.05, 0.01
t200_xl, t200_l = np.arange(0, 15 + step200_xl, step200_xl), np.arange(0, 15 + step200_l, step200_l)
t200_m, t200_s = np.arange(0, 15 + step200_m, step200_m), np.arange(0, 15 + step200_s, step200_s)

# The solution to the ODE 
x200_xl, _ = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step200_xl, c3)
x200_l, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step200_l, c3)
x200_m, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step200_m, c3)
x200_s, _  = euler_ode(dx_dt, dz_dt, [1, 0], [0, 15], step200_s, c3)

# Plot the resulting solutions
plt.figure(figsize=(18, 12), dpi=250)
plt.plot(t200_xl[:len(x200_xl)], x200_xl, label="x(t), k=40 N/m, h=%0.3f" % step200_xl)
plt.plot(t200_l, x200_l, label="x(t), k=40 N/m, h=%0.3f" % step200_l)
plt.plot(t200_m, x200_m, label="x(t), k=40 N/m, h=%0.3f" % step200_m)
plt.plot(t200_s, x200_s, label="x(t), k=40 N/m, h=%0.3f" % step200_s)
plt.xlabel("$t$ (s)")
plt.ylabel("$x$ (m)")
plt.grid(True)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# In each different solution to the differential equation, by testing different step sizes, numerical instability appears in each different case. This shows how the prevalence of this instability is dependent only on the step size, and not on the solution's shape itself. Especially since the first solution is sinusoidal, while the other two solutions are decaying exponentially.
